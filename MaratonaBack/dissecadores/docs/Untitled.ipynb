# %%
import sys
sys.path.append("../")

# %%
import os
import django
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "samsung.settings")
django.setup()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-d6e7e89cdd49> in <module>()
#       1 import os
# ----> 2 import django
#       3 os.environ.setdefault("DJANGO_SETTINGS_MODULE", "samsung.settings")
#       4 django.setup()
#
# ImportError: No module named django

# %%
from samsung.models import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-32ed13586ca7> in <module>()
# ----> 1 from samsung.models import *
#
# C:\Users\Azapfy\Documents\MaratonaSamsung-Back\MaratonaBack\dissecadores\samsung\models.py in <module>()
# ----> 1 from django.db import models
#       2
#       3 # Create your models here.
#       4
#       5 class Sintoma(models.Model):
#
# ImportError: No module named django.db

# %%
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\users\teteo\downloads\pos-manual-tagger\myvenvwindows\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# c:\users\teteo\downloads\pos-manual-tagger\myvenvwindows\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#
# LookupError:
# **********************************************************************
#   Resource machado not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('machado')
#
#   For more information see: https://www.nltk.org/data.html
#
# ...

# %%
# Out:
# ['God', 'is', 'Great', '!', 'I', 'won', 'a', 'lottery', '.']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5372b1ed450a> in <module>
#      16     term = Term.objects.get_or_create(name=palavra)
#      17     j=i+8
# ---> 18     TermOccurence.objects.create(order=j,document=document,term=term)
#      19
#      20
#
# c:\users\teteo\downloads\pos-manual-tagger\myvenvwindows\lib\site-packages\django\db\models\manager.py in manager_method(self, *args, **kwargs)
#      80         def create_method(name, method):
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#      84             manager_method.__doc__ = method.__doc__
#
# c:\users\teteo\downloads\pos-manual-tagger\myvenvwindows\lib\site-packages\django\db\models\query.py in create(self, **kwargs)
# ...

# %%
Term.objects.all()
# Out:
# <QuerySet [<Term: oi>, <Term: God>, <Term: is>, <Term: Great>, <Term: !>, <Term: I>, <Term: won>, <Term: a>, <Term: lottery>, <Term: .>, <Term: take>, <Term: Romance>]>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6b09081dd9a7> in <module>()
#       4
#       5 #depois fazer  um unique index
# ----> 6 task = Task.objects.create(name='verbo')
#       7 document = Document.objects.create(description="", document= "", uploaded_at="test", task=task)
#       8 text = "God is Great! I won a lottery."
#
# NameError: name 'Task' is not defined

# %%
Sintomas.objects.all()

# %%
# Out:
# ['Romance',
#  ',',
#  'Memórias',
#  'Póstumas',
#  'de',
#  'Brás',
#  'Cubas',
#  ',',
#  '1880',
#  'Memórias',
#  'Póstumas',
#  'de',
#  'Brás',
#  'Cubas',
#  'Texto-fonte',
#  ':',
#  'Obra',
#  'Completa',
#  ',',
#  'Machado',
#  'de',
#  'Assis',
#  ',',
#  'Rio',
#  'de',
#  'Janeiro',
#  ':',
#  'Editora',
#  'Nova',
#  'Aguilar',
#  ',',
#  '1994',
#  '.',
#  'Publicado',
#  'originalmente',
#  'em',
#  'folhetins',
#  ',',
#  'a',
#  'partir',
#  'de',
#  'março',
#  'de',
#  '1880',
#  ',',
#  'na',
#  'Revista',
#  'Brasileira',
#  '.',
#  'Ao',
#  'verme',
#  'que',
#  'primeiro',
#  'roeu',
#  'as',
#  'frias',
#  'carnes',
#  'do',
#  'meu',
#  'cadáver',
#  'dedico',
#  'como',
#  'saudosa',
#  'lembrança',
#  'estas',
#  'Memórias',
#  'Póstumas',
#  'Prólogo',
#  'da',
#  'terceira',
#  'edição',
#  'A',
#  'primeira',
#  'edição',
#  'destas',
#  'Memórias',
#  'Póstumas',
#  'de',
#  'Brás',
#  'Cubas',
#  'foi',
#  'feita',
#  'aos',
#  'pedaços',
#  'na',
# ...
